# %%
# !pip install earthkit
import earthkit as ek

data = ek.data.from_source(
    'cds',
    'reanalysis-era5-single-levels',
    {
        'product_type': 'reanalysis',
        'variable': '2m_temperature',
        'year': '2023',
        'month': '07',
        'day': '3',
        'time': '12:00',
    },
)

ek.plots.globe(data)
# Out:
# Collecting earthkit
#   Downloading earthkit-0.8.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting earthkit-data>=0.10.2 (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading earthkit_data-0.10.8-py3-none-any.whl.metadata (6.4 kB)
# Collecting earthkit-geo>=0.2.0 (from earthkit)
#   Downloading earthkit_geo-0.2.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting earthkit-meteo>=0.1.1 (from earthkit)
#   Downloading earthkit_meteo-0.1.1-py3-none-any.whl.metadata (3.3 kB)
# Collecting earthkit-plots>=0.2.0 (from earthkit)
#   Downloading earthkit_plots-0.2.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting earthkit-regrid>=0.3.4 (from earthkit)
#   Downloading earthkit_regrid-0.3.4-py3-none-any.whl.metadata (1.6 kB)
# Collecting earthkit-transforms>=0.3.3 (from earthkit)
#   Downloading earthkit_transforms-0.3.4-py3-none-any.whl.metadata (16 kB)
# Collecting cfgrib>=0.9.10.1 (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading cfgrib-0.9.14.1-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 12.5 MB/s eta 0:00:00
# Collecting dask (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading dask-2024.10.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting eccodes>=1.7 (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading eccodes-2.38.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: entrypoints in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (0.4)
# Requirement already satisfied: filelock in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (3.12.4)
# Requirement already satisfied: jinja2 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (3.1.2)
# Requirement already satisfied: jsonschema in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (3.2.0)
# Collecting lru-dict (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading lru_dict-1.3.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: markdown in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (3.5)
# Collecting multiurl (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading multiurl-0.3.1.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting netcdf4 (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading netCDF4-1.7.1.post2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: pandas in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (2.1.4)
# Collecting pdbufr>=0.11 (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading pdbufr-0.11.0.tar.gz (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 102.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pyyaml in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (6.0.1)
# Requirement already satisfied: tqdm>=4.63 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (4.66.1)
# Collecting xarray>=0.19 (from earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading xarray-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting cartopy (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading Cartopy-0.24.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Collecting cdsapi>=0.7.1 (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading cdsapi-0.7.3-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting eccovjson>=0.0.5 (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading eccovjson-0.0.5.tar.gz (11 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ecmwf-api-client>=1.6.1 (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading ecmwf-api-client-1.6.3.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ecmwf-opendata>=0.3.3 (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading ecmwf-opendata-0.3.10.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: geopandas in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-data[all]>=0.10.2->earthkit) (0.13.2)
# Collecting hda (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading hda-2.18.tar.gz (15 kB)
#   Preparing metadata (setup.py) ... done
# Collecting polytope-client>=0.7.4 (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading polytope_client-0.7.4-py3-none-any.whl.metadata (1.0 kB)
# Collecting pyfdb (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading pyfdb-0.0.1-py3-none-any.whl.metadata (821 bytes)
# Collecting pyodc (from earthkit-data[all]>=0.10.2->earthkit)
#   Downloading pyodc-1.4.1.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pyproj in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-geo>=0.2.0->earthkit) (3.6.1)
# Requirement already satisfied: scipy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-geo>=0.2.0->earthkit) (1.11.3)
# Requirement already satisfied: numpy in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-meteo>=0.1.1->earthkit) (1.26.1)
# Collecting earthkit-plots-default-styles (from earthkit-plots>=0.2.0->earthkit)
#   Downloading earthkit_plots_default_styles-0.0.1-py3-none-any.whl.metadata (1.2 kB)
# Collecting pint (from earthkit-plots>=0.2.0->earthkit)
#   Downloading Pint-0.24.3-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: matplotlib in /shared-libs/python3.11/py/lib/python3.11/site-packages (from earthkit-plots>=0.2.0->earthkit) (3.8.0)
# Collecting adjustText (from earthkit-plots>=0.2.0->earthkit)
#   Downloading adjustText-1.2.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting rasterio (from earthkit-transforms>=0.3.3->earthkit)
#   Downloading rasterio-1.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: shapely>=1.8 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from cartopy->earthkit-data[all]>=0.10.2->earthkit) (2.0.2)
# Requirement already satisfied: packaging>=21 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from cartopy->earthkit-data[all]>=0.10.2->earthkit) (23.2)
# Collecting pyshp>=2.3 (from cartopy->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 12.0 MB/s eta 0:00:00
# Collecting cads-api-client>=1.3.2 (from cdsapi>=0.7.1->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading cads_api_client-1.4.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: requests>=2.5.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from cdsapi>=0.7.1->earthkit-data[all]>=0.10.2->earthkit) (2.31.0)
# Requirement already satisfied: attrs>=19.2 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from cfgrib>=0.9.10.1->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (23.1.0)
# Requirement already satisfied: click in /shared-libs/python3.11/py/lib/python3.11/site-packages (from cfgrib>=0.9.10.1->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (8.1.7)
# Requirement already satisfied: cffi in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from eccodes>=1.7->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (1.16.0)
# Collecting findlibs (from eccodes>=1.7->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading findlibs-0.0.5.tar.gz (6.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->earthkit-plots>=0.2.0->earthkit) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->earthkit-plots>=0.2.0->earthkit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->earthkit-plots>=0.2.0->earthkit) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->earthkit-plots>=0.2.0->earthkit) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->earthkit-plots>=0.2.0->earthkit) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from matplotlib->earthkit-plots>=0.2.0->earthkit) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from matplotlib->earthkit-plots>=0.2.0->earthkit) (2.8.2)
# Requirement already satisfied: pytz in /shared-libs/python3.11/py/lib/python3.11/site-packages (from multiurl->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (2023.3.post1)
# Collecting docstring-parser (from polytope-client>=0.7.4->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading docstring_parser-0.16-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: certifi in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pyproj->earthkit-geo>=0.2.0->earthkit) (2023.7.22)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pandas->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (2024.1)
# Collecting cloudpickle>=3.0.0 (from dask->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: fsspec>=2021.09.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from dask->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (2023.9.2)
# Collecting partd>=1.4.0 (from dask->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: toolz>=0.10.0 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from dask->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (0.12.0)
# Collecting importlib-metadata>=4.13.0 (from dask->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: fiona>=1.8.19 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from geopandas->earthkit-data[all]>=0.10.2->earthkit) (1.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from jinja2->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (2.1.3)
# Requirement already satisfied: pyrsistent>=0.14.0 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from jsonschema->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (0.19.3)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.11/site-packages (from jsonschema->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (65.5.0)
# Requirement already satisfied: six>=1.11.0 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from jsonschema->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (1.16.0)
# Collecting cftime (from netcdf4->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading cftime-1.6.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Collecting appdirs>=1.4.4 (from pint->earthkit-plots>=0.2.0->earthkit)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.11/py/lib/python3.11/site-packages (from pint->earthkit-plots>=0.2.0->earthkit) (4.8.0)
# Collecting flexcache>=0.3 (from pint->earthkit-plots>=0.2.0->earthkit)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.3 (from pint->earthkit-plots>=0.2.0->earthkit)
#   Downloading flexparser-0.3.1-py3-none-any.whl.metadata (18 kB)
# Collecting affine (from rasterio->earthkit-transforms>=0.3.3->earthkit)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: cligj>=0.5 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from rasterio->earthkit-transforms>=0.3.3->earthkit) (0.7.2)
# Requirement already satisfied: click-plugins in /shared-libs/python3.11/py/lib/python3.11/site-packages (from rasterio->earthkit-transforms>=0.3.3->earthkit) (1.1.1)
# Collecting zipp>=3.20 (from importlib-metadata>=4.13.0->dask->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading zipp-3.20.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting locket (from partd>=1.4.0->dask->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit)
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests>=2.5.0->cdsapi>=0.7.1->earthkit-data[all]>=0.10.2->earthkit) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from requests>=2.5.0->cdsapi>=0.7.1->earthkit-data[all]>=0.10.2->earthkit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /shared-libs/python3.11/py/lib/python3.11/site-packages (from requests>=2.5.0->cdsapi>=0.7.1->earthkit-data[all]>=0.10.2->earthkit) (1.26.18)
# Requirement already satisfied: pycparser in /shared-libs/python3.11/py-core/lib/python3.11/site-packages (from cffi->eccodes>=1.7->earthkit-data>=0.10.2->earthkit-data[all]>=0.10.2->earthkit) (2.21)
# Downloading earthkit-0.8.0-py3-none-any.whl (7.3 kB)
# Downloading earthkit_data-0.10.8-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.0/277.0 kB 50.2 MB/s eta 0:00:00
# Downloading earthkit_geo-0.2.0-py3-none-any.whl (15 kB)
# Downloading earthkit_meteo-0.1.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 7.9 MB/s eta 0:00:00
# Downloading earthkit_plots-0.2.3-py3-none-any.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 96.0 MB/s eta 0:00:00
# Downloading earthkit_regrid-0.3.4-py3-none-any.whl (29 kB)
# Downloading earthkit_transforms-0.3.4-py3-none-any.whl (32 kB)
# Downloading Cartopy-0.24.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 117.7 MB/s eta 0:00:00
# Downloading cdsapi-0.7.3-py2.py3-none-any.whl (12 kB)
# Downloading cfgrib-0.9.14.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 10.5 MB/s eta 0:00:00
# Downloading eccodes-2.38.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 127.0 MB/s eta 0:00:00
# Downloading polytope_client-0.7.4-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 10.8 MB/s eta 0:00:00
# Downloading xarray-2024.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 98.0 MB/s eta 0:00:00
# Downloading adjustText-1.2.0-py3-none-any.whl (12 kB)
# Downloading dask-2024.10.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 92.5 MB/s eta 0:00:00
# Downloading earthkit_plots_default_styles-0.0.1-py3-none-any.whl (11 kB)
# Downloading lru_dict-1.3.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Downloading netCDF4-1.7.1.post2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 117.1 MB/s eta 0:00:00
# Downloading Pint-0.24.3-py3-none-any.whl (301 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.8/301.8 kB 52.3 MB/s eta 0:00:00
# Downloading pyfdb-0.0.1-py3-none-any.whl (6.1 kB)
# Downloading rasterio-1.4.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 93.7 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading cads_api_client-1.4.5-py3-none-any.whl (24 kB)
# Downloading cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.3.1-py3-none-any.whl (27 kB)
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 8.2 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading cftime-1.6.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.2 MB/s eta 0:00:00
# Downloading docstring_parser-0.16-py3-none-any.whl (36 kB)
# Downloading zipp-3.20.2-py3-none-any.whl (9.2 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Building wheels for collected packages: eccovjson, ecmwf-api-client, ecmwf-opendata, multiurl, pdbufr, hda, pyodc, findlibs
#   Building wheel for eccovjson (pyproject.toml) ... done
#   Created wheel for eccovjson: filename=eccovjson-0.0.5-py3-none-any.whl size=18801 sha256=5481177364bde9f687099f462985502eeb255caa5583286decab40b3585d2451
#   Stored in directory: /root/.cache/pip/wheels/96/5e/5f/14b3ec0c33d827ebed856c932da12063ed0e0b08c3f7307432
#   Building wheel for ecmwf-api-client (setup.py) ... done
#   Created wheel for ecmwf-api-client: filename=ecmwf_api_client-1.6.3-py3-none-any.whl size=13515 sha256=89da2140dbcc9d587e5b11b97eb45a973fc95efeae661bed210a4b2a1ae25ecf
#   Stored in directory: /root/.cache/pip/wheels/f4/d7/fb/8a555f6d74aad9ffe2ff296f9f912643c4a5f7017a23ec8554
#   Building wheel for ecmwf-opendata (setup.py) ... done
#   Created wheel for ecmwf-opendata: filename=ecmwf_opendata-0.3.10-py3-none-any.whl size=19949 sha256=d9dcc46e6bee30b43686237973968f71cc23cd4b23c55d18fea45f080d86922e
#   Stored in directory: /root/.cache/pip/wheels/2e/7d/07/747f057ee3f804782d335a7f30d27be19c0fcd05caaf065f67
#   Building wheel for multiurl (setup.py) ... done
#   Created wheel for multiurl: filename=multiurl-0.3.1-py3-none-any.whl size=21133 sha256=d3fadabc4a575681f37d2331d732c448670b2ff7bfa499de381aae9c57ec1f21
#   Stored in directory: /root/.cache/pip/wheels/88/54/66/4e1d7b60e01b6f962672d16bc2227061edd0af136327d6f9e4
#   Building wheel for pdbufr (pyproject.toml) ... done
#   Created wheel for pdbufr: filename=pdbufr-0.11.0-py3-none-any.whl size=22483 sha256=59dfdf1690d4fc599ca03ac2e8da4fceca417438e3dd504b5932ba4635f657d9
#   Stored in directory: /root/.cache/pip/wheels/a8/50/a8/f6bd3d2fada43bf22c495aef38df55c7481f79b85e35e5037c
#   Building wheel for hda (setup.py) ... done
#   Created wheel for hda: filename=hda-2.18-py3-none-any.whl size=15402 sha256=37642c85a36d3873ad84a3214c8d43d23e196245aa0b5eceba284ba7d22fa910
#   Stored in directory: /root/.cache/pip/wheels/b4/0e/68/cf914934e84836630b0067d0ad873ab38a26554314cfef8265
#   Building wheel for pyodc (pyproject.toml) ... done
#   Created wheel for pyodc: filename=pyodc-1.4.1-py3-none-any.whl size=30466 sha256=79272ab8326b659ce6dbd9ed48977abce1d51b256a86fe0abab404ce7e037e04
#   Stored in directory: /root/.cache/pip/wheels/64/42/8d/94bd5036be2f054f688aaa41e27b4e7696631d6dd653e1a3d9
#   Building wheel for findlibs (setup.py) ... done
#   Created wheel for findlibs: filename=findlibs-0.0.5-py3-none-any.whl size=6943 sha256=0724a142b6fd8c88eb0dad158dfdc39ed521f593d350b436a17600d4fee165dd
#   Stored in directory: /root/.cache/pip/wheels/e5/eb/3a/fc9bb01081f51631725acecba7bbfcdd14a53765635ffe11f5
# Successfully built eccovjson ecmwf-api-client ecmwf-opendata multiurl pdbufr hda pyodc findlibs
# Installing collected packages: pyfdb, findlibs, ecmwf-api-client, eccovjson, appdirs, zipp, pyshp, lru-dict, locket, flexparser, flexcache, earthkit-plots-default-styles, earthkit-meteo, docstring-parser, cloudpickle, cftime, affine, rasterio, polytope-client, pint, partd, netcdf4, multiurl, importlib-metadata, hda, eccodes, earthkit-geo, xarray, pyodc, pdbufr, ecmwf-opendata, earthkit-regrid, dask, cfgrib, cartopy, cads-api-client, adjustText, earthkit-data, cdsapi, earthkit-transforms, earthkit-plots, earthkit
# Successfully installed adjustText-1.2.0 affine-2.4.0 appdirs-1.4.4 cads-api-client-1.4.5 cartopy-0.24.1 cdsapi-0.7.3 cfgrib-0.9.14.1 cftime-1.6.4 cloudpickle-3.1.0 dask-2024.10.0 docstring-parser-0.16 earthkit-0.8.0 earthkit-data-0.10.8 earthkit-geo-0.2.0 earthkit-meteo-0.1.1 earthkit-plots-0.2.3 earthkit-plots-default-styles-0.0.1 earthkit-regrid-0.3.4 earthkit-transforms-0.3.4 eccodes-2.38.3 eccovjson-0.0.5 ecmwf-api-client-1.6.3 ecmwf-opendata-0.3.10 findlibs-0.0.5 flexcache-0.3 flexparser-0.3.1 hda-2.18 importlib-metadata-8.5.0 locket-1.0.0 lru-dict-1.3.0 multiurl-0.3.1 netcdf4-1.7.1.post2 partd-1.4.2 pdbufr-0.11.0 pint-0.24.3 polytope-client-0.7.4 pyfdb-0.0.1 pyodc-1.4.1 pyshp-2.3.1 rasterio-1.4.1 xarray-2024.9.0 zipp-3.20.2
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# <div style='border: 1px solid orange; color: black;
#      background-color: rgb(255, 214, 0);
#      margin: 0.5em; padding: 0.5em; font-weight: bold;'>
# <p>An API key is needed to access this dataset. Please visit
# <a href="https://cds.climate.copernicus.eu/">https://cds.climate.copernicus.eu/</a> to register or sign-in
# then visit <a href="https://cds.climate.copernicus.eu/api-how-to">https://cds.climate.copernicus.eu/api-how-to</a> to retrieve you API key.</p>
# <p>You can store the credentials in ~/.cdsapirc or in the file
# pointed by the CDSAPI_RC environment variable. If you follow
# the instructions below ~/.cdsapirc will be automatically created
# for you.
#  Alternatively, you can use the CDSAPI_URL and CDSAPI_KEY environment variables to specify the credentials.</p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API url</span> or leave empty for the default value <span style='color: red;'>https://cds.climate.copernicus.eu/api/v2</span>, then press <em>ENTER</em></p>
# </div>
# <div style='border: 1px solid gray; color: black;
#      background-color: rgb(230, 230, 230);
#      margin: 0.2em; padding: 0.2em; font-weight: bold;'>
# <p>Please enter a value for <span style='color: red;'>API key</span>, then press <em>ENTER</em> The value should look like  <span style='color: red;'>123:abcdef01-0000-1111-2222-0123456789ab</span></p>
# </div>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=200afad5-8991-4e20-8a55-8751c7aff3b5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
